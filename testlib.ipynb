# %%
from lib.city import *
from lib.visualize import *


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
color_palette = sns.color_palette("muted")
sns.set_palette(color_palette)

# %%
city = gen_city_df(10, 0, 100)
city
# Out:
#     x   y
# 0  43  50
# 1  37  17
# 2  74  61
# 3  82  63
# 4  16  18
# 5   7  70
# 6  13  51
# 7  62  37
# 8  58  29
# 9   8  95

# %%
distance = cal_distance_matrix(city)

# %%
plt.figure(figsize=(21, 9), dpi=80)
distance_heatmap(distance)

# %%
route = np.arange(0, len(city))

plt.figure(figsize=(8, 8), dpi=100)
visualize_route(city, route)

# %%
calculate_distance(distance_df=distance, route=route)
# Out:
# 451.56
